# %% [markdown]
# # Assignment: GDP Analysis

# %%
#imported the required liberary

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline # Magic line which help not to write each plt.show()

# %% [markdown]
# # Part I-A:

# %%
# loaded the data GSDP 

GSDP = pd.read_csv(r'C:\Users\Admin\Downloads\GDP Assignment\Data I-A download\GSDP.csv')

# %%
#data View of GSDP

GSDP.head()
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15         526468.0
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
# 3            16761.0  198098.0  373920.0      234982.0  40633.0  895027.0
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana  ...  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 0  297539.0  ...   359433.0  19208.0       724049.0     115523.0
# ...

# %%
#data shape of GSDP

GSDP.shape
# Out:
# (11, 36)

# %% [markdown]
# ### Missing Data
# ###### We can use seaborn to create a simple heatmap to see where we are missing data!

# %%
# count the Null values present in dateset

GSDP.isnull().sum()
# Out:
# Items  Description            0
# Duration                      0
# Andhra Pradesh                0
# Arunachal Pradesh             2
# Assam                         2
# Bihar                         2
# Chhattisgarh                  0
# Goa                           2
# Gujarat                       2
# Haryana                       0
# Himachal Pradesh              4
# Jammu & Kashmir               2
# Jharkhand                     2
# Karnataka                     2
# Kerala                        2
# Madhya Pradesh                0
# Maharashtra                   4
# Manipur                       4
# Meghalaya                     0
# Mizoram                       4
# Nagaland                      4
# Odisha                        0
# Punjab                        4
# Rajasthan                     4
# Sikkim                        2
# Tamil Nadu                    0
# Telangana                     0
# Tripura                       4
# Uttar Pradesh                 2
# ...

# %%
#Count the null values sum in rows  wise

GSDP.isnull().sum(axis=1)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4     10
# 5     23
# 6      1
# 7      1
# 8      1
# 9     10
# 10    23
# dtype: int64

# %% [markdown]
# ## Missing Data
# * We can use seaborn to create a simple heatmap to see where we are missing data!

# %%
#heat map to show the null value where present and its east to visual

plt.figure(figsize=(14, 4))

sns.heatmap(GSDP.isnull(),cbar=False,cmap='viridis')

# %% [markdown]
# ##### We can see here that two rows and one colmumn has lots of Null value.
#
# * Rows - 5th and 23th i.e Duration - 2016-17
# * Coulmns - West-Bengal
#
# #####  Now we will remove the data for Rows - 5th and 23th i.e Duration - 2016-17 and Coulmns - West-Bengal

# %%
#### Updated dataframe now is GSDP_Updated

# Removing the columns = 'West Bengal1'
GSDP_Updated = GSDP.drop(columns= ['West Bengal1'])

# %%
# Removiing the Duration - 2016-17- % growth and GSDP current prices. from GSDP_Updated dataframe

GSDP_Updated = GSDP_Updated[GSDP_Updated.Duration != '2016-17']

# %%
# Earlier shape was 11*36 but now after removing the 2 rows and 1 columns shape is 9*35

GSDP_Updated.shape
# Out:
# (9, 35)

# %%
# Now the null values count

plt.figure(figsize=(14, 4))

sns.heatmap(GSDP_Updated.isnull(),cbar=False,cmap='viridis')

# %%
# shape of the dataframe 
GSDP_Updated.shape
# Out:
# (9, 35)

# %%
## Now remving the union territory from the GSDP_Updated and created the new dataframe GSDP_Updated_states
## Droping four columns -> 'Andaman & Nicobar Islands' , 'Chandigarh','Delhi' and 'Puducherry'

GSDP_Updated_states = GSDP_Updated.drop(columns= ['Andaman & Nicobar Islands' , 'Chandigarh','Delhi','Puducherry'], axis = 1)

# %%
# Now, I have the dataframe GSDP_Updated_states 9 rows and 31 columns

GSDP_Updated_states.shape
# Out:
# (9, 31)

# %%
# data set with all required states which needed
GSDP_Updated_states
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
#filtering the data for year 2013-14,2014-15,2015-16  of % Growth over previous year)

GSDP_per_growth_states = GSDP_Updated_states[((GSDP_Updated_states.Duration =='2013-14')|(GSDP_Updated_states.Duration =='2014-15')|(GSDP_Updated_states.Duration=='2015-16'))&(GSDP_Updated_states["Items  Description"]=='(% Growth over previous year)')]

# %%
# filtered data of 2013-14,2014-15,2015-16

GSDP_per_growth_states
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 7  (% Growth over previous year)  2013-14            12.85              16.38
# 8  (% Growth over previous year)  2014-15            13.40              14.79
# 9  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana  ...  Odisha  Punjab  \
# 7  13.31  12.30         16.44  -5.77    11.47    15.45  ...   12.95   12.42
# 8  11.45  17.92         13.69  13.12    10.82     9.18  ...   10.37    9.95
# 9  13.19  10.59         10.98  10.75    11.09    10.91  ...    6.19     NaN
#
#    Rajasthan  Sikkim  Tamil Nadu  Telangana  Tripura  Uttar Pradesh  \
# 7      11.27   12.35       13.51      12.63    18.14          14.73
# 8      11.37    9.72       12.51      13.05    15.92          10.51
# 9        NaN    9.39       10.99      12.61      NaN          10.58
#
#    Uttarakhand  All_India GDP
# 7        13.64          12.97
# ...

# %% [markdown]
# ## Task 1 -:
#
# #### Plot a graph for rows " % Growth over previous year" for all the states (not union territories) whose data is available, use as much data as possible for this exercise. Use the best fit line to represent the growth for each state. Draw a similar line graph for the nation as well.

# %%
# filtering the states and storing in States

States = []
States = GSDP_per_growth_states.columns

# %%
# states which I need to plot the best fit line
States
# Out:
# Index(['Items  Description', 'Duration', 'Andhra Pradesh ',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'All_India GDP'],
#       dtype='object')

# %%
# states which I need to plot the best fit line
States_list = States[2:-1]

# %%
# states which I need to plot the best fit line
States_list
# Out:
# Index(['Andhra Pradesh ', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand'],
#       dtype='object')

# %%
# Now addding one column and Year and naming as 1, 2 and 3 and 

# 2013-14-->1
# 2014-15-->2
# 2015-16-->3

GSDP_per_growth_staes ['Year'] = [1,2,3]
GSDP_per_growth_staes['Year']
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# 7    1
# 8    2
# 9    3
# Name: Year, dtype: int64

# %%
# We have some vaules in GSDP_per_growth_states which is Null so I am filling those data as mean

for i in States_list:
    GSDP_per_growth_staes[i].fillna(GSDP_per_growth_staes[i].mean(axis = 0) , inplace = True)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
# checking the null values 
GSDP_per_growth_staes.isnull().sum()
# Out:
# Items  Description    0
# Duration              0
# Andhra Pradesh        0
# Arunachal Pradesh     0
# Assam                 0
# Bihar                 0
# Chhattisgarh          0
# Goa                   0
# Gujarat               0
# Haryana               0
# Himachal Pradesh      0
# Jammu & Kashmir       0
# Jharkhand             0
# Karnataka             0
# Kerala                0
# Madhya Pradesh        0
# Maharashtra           0
# Manipur               0
# Meghalaya             0
# Mizoram               0
# Nagaland              0
# Odisha                0
# Punjab                0
# Rajasthan             0
# Sikkim                0
# Tamil Nadu            0
# Telangana             0
# Tripura               0
# Uttar Pradesh         0
# Uttarakhand           0
# All_India GDP         0
# Year                  0
# dtype: int64

# %%
# ploting the best fit line for all the states for below years:

# 2013-14-->1
# 2014-15-->2
# 2015-16-->3

j=1
for i in States_list:
    plt.subplot(7,4,j)
    m, c = np.polyfit(GSDP_per_growth_staes['Year'],GSDP_per_growth_staes[i],1 )
    plt.scatter(x = 'Year', y = i , data = GSDP_per_growth_staes)
    plt.xlabel('Year')
    plt.plot(GSDP_per_growth_staes['Year'], m*GSDP_per_growth_staes['Year']+c, '--r')
    j= j+1
plt.savefig(r'C:\Users\Admin\Downloads\GDP Assignment\Graph\best fit line for all the states.png')

# %% [markdown]
# ###  How will you compare the growth rates of any two states?
#
# #### Answer: As I have plotted  the best fit plot for each states and growing line saying that for each year will tell that % Growth
#    #### Next plot will show you how the Average graph for this % Growth over previous year

# %%
# Now, plotting the Average graph for this % Growth over previous year

# calculting the mean now for this GSDP_per_growth_staes
# round the value with 2 decimal places

Mean_percent_growth_year = round(GSDP_per_growth_staes.mean(),2)

# %%
Mean_percent_growth_year
# Out:
# Andhra Pradesh       14.03
# Arunachal Pradesh    14.41
# Assam                12.65
# Bihar                13.60
# Chhattisgarh         13.70
# Goa                   6.03
# Gujarat              11.13
# Haryana              11.85
# Himachal Pradesh     12.28
# Jammu & Kashmir      10.90
# Jharkhand            11.50
# Karnataka            14.12
# Kerala               12.58
# Madhya Pradesh       12.63
# Maharashtra          11.26
# Manipur              14.61
# Meghalaya             6.95
# Mizoram              17.70
# Nagaland             16.42
# Odisha                9.84
# Punjab               11.18
# Rajasthan            11.32
# Sikkim               10.49
# Tamil Nadu           12.34
# Telangana            12.76
# Tripura              17.03
# Uttar Pradesh        11.94
# Uttarakhand          11.80
# All_India GDP        11.20
# Year                  2.00
# dtype: float64

# %%
#Transpose the GSDP_Updated for better understanding as also we can add the column the mean % Growth year for states
#i.e Mean_percent_growth_year

GSDP_Updated_states= GSDP_Updated_states.transpose()

# %%
# Shape will change now

GSDP_Updated_states.shape
# Out:
# (31, 9)

# %%
# See the Transpose the GSDP_Updated
GSDP_Updated_states
# Out:
#                                                      0  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Duration                                       2011-12
# Andhra Pradesh                                  379402
# Arunachal Pradesh                                11063
# Assam                                           143175
# Bihar                                           247144
# Chhattisgarh                                    158074
# Goa                                              42367
# Gujarat                                         615606
# Haryana                                         297539
# Himachal Pradesh                                 72720
# Jammu & Kashmir                                  78254
# Jharkhand                                       150918
# Karnataka                                       603778
# Kerala                                          364048
# Madhya Pradesh                                  315561
# ...

# %%
# add the mean value columns value now

GSDP_Updated_states["Mean Percent Growth"]= Mean_percent_growth_year

# %%
GSDP_Updated_states
# Out:
#                                                      0  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Duration                                       2011-12
# Andhra Pradesh                                  379402
# Arunachal Pradesh                                11063
# Assam                                           143175
# Bihar                                           247144
# Chhattisgarh                                    158074
# Goa                                              42367
# Gujarat                                         615606
# Haryana                                         297539
# Himachal Pradesh                                 72720
# Jammu & Kashmir                                  78254
# Jharkhand                                       150918
# Karnataka                                       603778
# Kerala                                          364048
# Madhya Pradesh                                  315561
# ...

# %%
# setting the index to 1st columns i.e states

GSDP_Updated_states = GSDP_Updated_states.reset_index()
GSDP_Updated_states
# Out:
#                  index                                   0  \
# 0   Items  Description  GSDP - CURRENT PRICES (` in Crore)
# 1             Duration                             2011-12
# 2      Andhra Pradesh                               379402
# 3    Arunachal Pradesh                               11063
# 4                Assam                              143175
# 5                Bihar                              247144
# 6         Chhattisgarh                              158074
# 7                  Goa                               42367
# 8              Gujarat                              615606
# 9              Haryana                              297539
# 10    Himachal Pradesh                               72720
# 11     Jammu & Kashmir                               78254
# 12           Jharkhand                              150918
# 13           Karnataka                              603778
# 14              Kerala                              364048
# ...

# %%
# desired data where need to plot the grapd to analyse the Mean % Growth
GSDP_Updated_states[2::]
# Out:
#                 index            0            1            2            3  \
# 2     Andhra Pradesh        379402       411404       464272       526468
# 3   Arunachal Pradesh        11063        12547        14602        16761
# 4               Assam       143175       156864       177745       198098
# 5               Bihar       247144       282368       317101       373920
# 6        Chhattisgarh       158074       177511       206690       234982
# 7                 Goa        42367        38120        35921        40633
# 8             Gujarat       615606       724495       807623       895027
# 9             Haryana       297539       347032       400662       437462
# 10   Himachal Pradesh        72720        82820        94764       104369
# 11    Jammu & Kashmir        78254        87105        95893       100404
# 12          Jharkhand       150918       174724       188567       217107
# 13          Karnataka       603778       691700       817886       921788
# ...

# %%
df = GSDP_Updated_states[2::]
df = df.sort_values('Mean Percent Growth')

plt.figure(figsize=(10, 10))
plt.title('Mean % Growths over years')
sns.barplot(x='Mean Percent Growth', y=df['index'], data=df)
plt.savefig(r'C:\Users\Admin\Downloads\GDP Assignment\Graph\Mean % Growths over years.png')

# %% [markdown]
# ### Which states have been growing consistently fast, and which ones have been struggling? Rank top 3 fastest and 3 slowest-growing states.
#
# #### Answer: As per above graph we can compare the growth rate of any two states. Top 3 fastest growing states: Mizoram, Nagaland and Tripura  and Slowest 3 -growing states: Goa, Meghalaya and Odisha
#
# ### What is the Nation's growth rate?
#
# #### Answer: All_India GDP- 11.20
#
#
# ### What has been the growth rate of your home state, and how does it compare to the national growth rate?
#
# #### Answer:11.94 for Uttar Pradesh. 0.74 is more as compare to All_India GDP- 11.20

# %% [markdown]
# ## Task 2:
#
# #### Plot the total GDP of the states for the year 2015-16:

# %%
# copy the dataframe to Total_GDP
Total_GDP = GSDP

# %%
# view the dataframe
Total_GDP.head(12)
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
# 2015-16 data fetched and stored
Total_GDP_2015_16 = Total_GDP[(Total_GDP.Duration=='2015-16')&(Total_GDP['Items  Description']=='GSDP - CURRENT PRICES (` in Crore)')]

# %%
# viewing the same data of 2015-16
Total_GDP_2015_16
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana  ...  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 4  485184.0  ...   575631.0      NaN      1153795.0     184091.0
#
#    West Bengal1  Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  \
# 4           NaN                        NaN     30304.0  551963.0     26533.0
#
#    All_India GDP
# 4     13675331.0
#
# [1 rows x 36 columns]

# %%
Total_GDP_2015_16 = Total_GDP_2015_16.transpose()

# %%
# reset the index for this data
Total_GDP_2015_16 = Total_GDP_2015_16.reset_index()

# %%
Total_GDP_2015_16
# Out:
#                         index                                   4
# 0          Items  Description  GSDP - CURRENT PRICES (` in Crore)
# 1                    Duration                             2015-16
# 2             Andhra Pradesh                               609934
# 3           Arunachal Pradesh                               18784
# 4                       Assam                              224234
# 5                       Bihar                              413503
# 6                Chhattisgarh                              260776
# 7                         Goa                               45002
# 8                     Gujarat                              994316
# 9                     Haryana                              485184
# 10           Himachal Pradesh                                 NaN
# 11            Jammu & Kashmir                              118387
# 12                  Jharkhand                              241955
# ...

# %%
#changing the column names

Total_GDP_2015_16.columns = ['States','Price']

# %%
Total_GDP_2015_16
# Out:
#                        States                               Price
# 0          Items  Description  GSDP - CURRENT PRICES (` in Crore)
# 1                    Duration                             2015-16
# 2             Andhra Pradesh                               609934
# 3           Arunachal Pradesh                               18784
# 4                       Assam                              224234
# 5                       Bihar                              413503
# 6                Chhattisgarh                              260776
# 7                         Goa                               45002
# 8                     Gujarat                              994316
# 9                     Haryana                              485184
# 10           Himachal Pradesh                                 NaN
# 11            Jammu & Kashmir                              118387
# 12                  Jharkhand                              241955
# ...

# %%
# changing the values of this columns to numeric

Total_GDP_2015_16['Price'] = pd.to_numeric(Total_GDP_2015_16['Price'],downcast='integer', errors='coerce')

# %%
Total_GDP_2015_16
# Out:
#                        States       Price
# 0          Items  Description         NaN
# 1                    Duration         NaN
# 2             Andhra Pradesh     609934.0
# 3           Arunachal Pradesh     18784.0
# 4                       Assam    224234.0
# 5                       Bihar    413503.0
# 6                Chhattisgarh    260776.0
# 7                         Goa     45002.0
# 8                     Gujarat    994316.0
# 9                     Haryana    485184.0
# 10           Himachal Pradesh         NaN
# 11            Jammu & Kashmir    118387.0
# 12                  Jharkhand    241955.0
# 13                  Karnataka   1027068.0
# 14                     Kerala    588337.0
# 15             Madhya Pradesh    543975.0
# 16                Maharashtra         NaN
# 17                    Manipur         NaN
# 18                  Meghalaya     26745.0
# 19                    Mizoram         NaN
# 20                   Nagaland         NaN
# ...

# %%
# removing Items Description and Duaration row as not required here

Total_GDP_2015_16=Total_GDP_2015_16.drop(Total_GDP_2015_16.index[0])
Total_GDP_2015_16=Total_GDP_2015_16.drop(Total_GDP_2015_16.index[0])

# %%
Total_GDP_2015_16
# Out:
#                        States       Price
# 2             Andhra Pradesh     609934.0
# 3           Arunachal Pradesh     18784.0
# 4                       Assam    224234.0
# 5                       Bihar    413503.0
# 6                Chhattisgarh    260776.0
# 7                         Goa     45002.0
# 8                     Gujarat    994316.0
# 9                     Haryana    485184.0
# 10           Himachal Pradesh         NaN
# 11            Jammu & Kashmir    118387.0
# 12                  Jharkhand    241955.0
# 13                  Karnataka   1027068.0
# 14                     Kerala    588337.0
# 15             Madhya Pradesh    543975.0
# 16                Maharashtra         NaN
# 17                    Manipur         NaN
# 18                  Meghalaya     26745.0
# 19                    Mizoram         NaN
# 20                   Nagaland         NaN
# 21                     Odisha    341887.0
# 22                     Punjab         NaN
# ...

# %%
# shape of this dataframe
Total_GDP_2015_16.shape
# Out:
# (34, 2)

# %%
#sorting the data in ascending order

Total_GDP_2015_16= Total_GDP_2015_16.sort_values(by=['Price'],ascending= True)

# %%
Total_GDP_2015_16
# Out:
#                        States       Price
# 24                     Sikkim     16637.0
# 3           Arunachal Pradesh     18784.0
# 34                 Puducherry     26533.0
# 18                  Meghalaya     26745.0
# 32                 Chandigarh     30304.0
# 7                         Goa     45002.0
# 11            Jammu & Kashmir    118387.0
# 29                Uttarakhand    184091.0
# 4                       Assam    224234.0
# 12                  Jharkhand    241955.0
# 6                Chhattisgarh    260776.0
# 21                     Odisha    341887.0
# 5                       Bihar    413503.0
# 9                     Haryana    485184.0
# 15             Madhya Pradesh    543975.0
# 33                      Delhi    551963.0
# 26                  Telangana    575631.0
# 14                     Kerala    588337.0
# 2             Andhra Pradesh     609934.0
# 8                     Gujarat    994316.0
# 13                  Karnataka   1027068.0
# ...

# %%
# dropped the NA values of this sorted data
Total_GDP_2015_16.sort_values(by = 'Price').dropna()
# Out:
#                States       Price
# 24             Sikkim     16637.0
# 3   Arunachal Pradesh     18784.0
# 34         Puducherry     26533.0
# 18          Meghalaya     26745.0
# 32         Chandigarh     30304.0
# 7                 Goa     45002.0
# 11    Jammu & Kashmir    118387.0
# 29        Uttarakhand    184091.0
# 4               Assam    224234.0
# 12          Jharkhand    241955.0
# 6        Chhattisgarh    260776.0
# 21             Odisha    341887.0
# 5               Bihar    413503.0
# 9             Haryana    485184.0
# 15     Madhya Pradesh    543975.0
# 33              Delhi    551963.0
# 26          Telangana    575631.0
# 14             Kerala    588337.0
# 2     Andhra Pradesh     609934.0
# 8             Gujarat    994316.0
# 13          Karnataka   1027068.0
# 28      Uttar Pradesh   1153795.0
# 25         Tamil Nadu   1212668.0
# 35      All_India GDP  13675331.0

# %%
# need to check if we need remove the UN or not here later on

#plot the GSDP prices vs the states

df3 = Total_GDP_2015_16 # copying the df for this plot
df3 = df3 = df3.drop([35]) # Removing All_India GDP
sns.set(style='white')

plt.figure(figsize=(15,10))
plt.title('Total GDP of the states year 2015-2016')
sns.barplot(y='States',x= 'Price',data=df3.sort_values(by = 'Price').dropna())
plt.savefig(r'C:\Users\Admin\Downloads\GDP Assignment\Graph\StatevsPrice.png')

# %% [markdown]
# #### Which Plot will you use for this? Why? (Remeber to plot the graph in a way such as it is easier to read and compare)
#
# ##### Answer: I used the bar graph to plot total GDP of the states for the year 2015-16
#
# #### Identify the top 5 and the bottom 5 states based on total GDP.
#
# ##### Answer: Top 5 States: Tamil Nadu, Uttar Pradesh, Karnataka, Gujarat and Andhra Pradesh and Bottom 5 States: Sikkim, Arunachal Pradesh, Puduchery, Meghalaya and Chandigarh
#
#
# #### What insights can you draw from this graph? What states are performing poorly?
# #### (Remember: this will not be solely based on total GDP)
#
# ##### Answer: Goa and Meghalaya states are performing poorly.

# %% [markdown]
# # Part I -B :

# %%
# importing the lib for reading the file using globe
import glob

# %%
path = r'C:\Users\Admin\Downloads\GDP Assignment\Data I-B download'
all_files = glob.glob(path+'/*.csv')

# %%
# importing the data of all the states
li = []
for file in all_files:
    df = pd.read_csv(file,encoding='latin1')
    df = df[['Item', '2014-15']]
    df = df.T
    df.columns = df.iloc[0]
    df = df[1:]
    df['States'] = file.split('\\')[-1].split('-')[1]
    li.append(df)

# %%
# after loading concat the data to single and desired format

All_States = pd.concat(li, axis = 0, ignore_index=True, sort= False)

# %%
# All_States null value check

All_States.isnull().sum()
# Out:
# Agriculture, forestry and fishing                                        0
# Crops                                                                    0
# Livestock                                                                0
# Forestry and logging                                                     0
# Fishing and aquaculture                                                  0
# Mining and quarrying                                                     1
# Primary                                                                  0
# Manufacturing                                                            0
# Electricity, gas, water supply & other utility services                  0
# Construction                                                             0
# Secondary                                                                0
# Trade, repair, hotels and restaurants                                    0
# ...

# %% [markdown]
# # Data cleaning
#
# ### Below are the columns are having maximum null values and so need to drop
#
# ###### Services incidental to transport*                                       27
# ###### Trade & repair services*                                                29
# ###### Road transport**                                                        29
# ###### Road transport*                                                         29

# %%
# as plotted the heat map for this and we can see the last threee rows are having more yellow 

plt.figure(figsize=(14, 4))

sns.heatmap(All_States.isnull(),cbar=False,cmap='viridis')

# %%
# droping the coulmuns which having max null values

All_States = All_States.drop(columns= ["Services incidental to transport*", "Trade & repair services*", "Road transport**", "Road transport*"])

# %%
All_States.head()
# Out:
#   Agriculture, forestry and fishing    Crops Livestock Forestry and logging  \
# 0                          14819416  7893514   4309078               346160
# 1                            686117   415520     38387               224017
# 2                           3855548  2890544    173478               261987
# 3                           7951890  4688237   2060296               550132
# 4                             16233     1659     13992                  388
#
#   Fishing and aquaculture Mining and quarrying   Primary Manufacturing  \
# 0                 2270664              1484300  16303716       4672266
# 1                    8193                30842    716959         26120
# 2                  529539              1471149   5326697       2002936
# 3                  653224                68107   8019997       2189965
# 4                     194                  179     16412        149631
#
#   Electricity, gas, water supply & other utility services Construction  ...  \
# ...

# %%
# Bring the States column to 1st columns

mid = All_States['States']
All_States.drop(labels=['States'], axis=1,inplace = True)
All_States.insert(0, 'States', mid)

# %%
All_States.head()
# Out:
#               States Agriculture, forestry and fishing    Crops Livestock  \
# 0     Andhra_Pradesh                          14819416  7893514   4309078
# 1  Arunachal_Pradesh                            686117   415520     38387
# 2              Assam                           3855548  2890544    173478
# 3              Bihar                           7951890  4688237   2060296
# 4         Chandigarh                             16233     1659     13992
#
#   Forestry and logging Fishing and aquaculture Mining and quarrying   Primary  \
# 0               346160                 2270664              1484300  16303716
# 1               224017                    8193                30842    716959
# 2               261987                  529539              1471149   5326697
# 3               550132                  653224                68107   8019997
# 4                  388                     194                  179     16412
#
# ...

# %%
# final Null check of this dataframe
All_States.isnull().sum()
# Out:
# States                                                                  0
# Agriculture, forestry and fishing                                       0
# Crops                                                                   0
# Livestock                                                               0
# Forestry and logging                                                    0
# Fishing and aquaculture                                                 0
# Mining and quarrying                                                    1
# Primary                                                                 0
# Manufacturing                                                           0
# Electricity, gas, water supply & other utility services                 0
# Construction                                                            0
# Secondary                                                               0
# Trade, repair, hotels and restaurants                                   0
# ...

# %%
# removing the UN states
All_States.drop([6], inplace = True)
All_States.drop([4], inplace = True)
All_States.drop([21], inplace = True)

# %%
All_States.head()
# Out:
#               States Agriculture, forestry and fishing    Crops Livestock  \
# 0     Andhra_Pradesh                          14819416  7893514   4309078
# 1  Arunachal_Pradesh                            686117   415520     38387
# 2              Assam                           3855548  2890544    173478
# 3              Bihar                           7951890  4688237   2060296
# 5       Chhattisgarh                           3948847  2613371    352208
#
#   Forestry and logging Fishing and aquaculture Mining and quarrying   Primary  \
# 0               346160                 2270664              1484300  16303716
# 1               224017                    8193                30842    716959
# 2               261987                  529539              1471149   5326697
# 3               550132                  653224                68107   8019997
# 5               597785                  385483              2451970   6400817
#
# ...

# %%
# ploting the graph for The GDP per capita for all the states

plt.figure(figsize=(20,12))
sns.set_style('whitegrid')
plt.title("The GDP per capita for all the states")
sns.barplot(y='States',x='Per Capita GSDP (Rs.)',data= All_States.sort_values('Per Capita GSDP (Rs.)'))
plt.savefig(r'C:\Users\Admin\Downloads\GDP Assignment\Graph\The GDP per capita for all the states.png')

# %%
Ratio_Highest_to_lowest = All_States['Per Capita GSDP (Rs.)'].max() / All_States['Per Capita GSDP (Rs.)'].min()
Ratio_Highest_to_lowest
# Out:
# 8.004741709371503

# %% [markdown]
# #### Plot the GDP per capita for all the states.
#
# #### Ans: Plotted the bar graph for this as you can see above
#
# #### Identify the top 5 and the bottom 5 states based on the GDP per capita.
# #### Ans:Top-5 states : Uttarkand, Kerala, Haryana, Sikkim and Goa and Bottom-5 states: Bihar, Uttar Pradesh, Manipur, Assam and Jharkhand
#
#
# #### Find the ratio of the highest per capita GDP to the lowest per capita GDP
# #### Ans: 8.0047

# %%
# percent of Contribution of Primary Sector

All_States['% Primary Contribution'] = (All_States['Primary']/All_States['Gross State Domestic Product'])*100

# %%
# percent of Contribution of Secondary Sector

All_States['% Secondary Contribution'] = (All_States['Secondary']/All_States['Gross State Domestic Product'])*100

# %%
# percent of Contribution of Tertiary Sector
All_States['% Tertiary Contribution'] = (All_States['Tertiary']/All_States['Gross State Domestic Product'])*100

# %%
# all clumns of this dataframe

All_States.columns
# Out:
# Index(['States', 'Agriculture, forestry and fishing', 'Crops', 'Livestock',
#        'Forestry and logging', 'Fishing and aquaculture',
#        'Mining and quarrying', 'Primary', 'Manufacturing',
#        'Electricity, gas, water supply & other utility services',
#        'Construction', 'Secondary', 'Trade, repair, hotels and restaurants',
#        'Trade & repair services', 'Hotels & restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Railways', 'Road transport', 'Water transport', 'Air transport',
#        'Services incidental to transport', 'Storage',
#        'Communication & services related to broadcasting',
#        'Financial services',
#        'Real estate, ownership of dwelling & professional services',
#        'Public administration', 'Other services', 'Tertiary',
#        'TOTAL GSVA at basic prices', 'Taxes on Products',
#        'Subsidies on products', 'Gross State Domestic Product',
# ...

# %%
All_States.head()
# Out:
#               States Agriculture, forestry and fishing    Crops Livestock  \
# 0     Andhra_Pradesh                          14819416  7893514   4309078
# 1  Arunachal_Pradesh                            686117   415520     38387
# 2              Assam                           3855548  2890544    173478
# 3              Bihar                           7951890  4688237   2060296
# 5       Chhattisgarh                           3948847  2613371    352208
#
#   Forestry and logging Fishing and aquaculture Mining and quarrying   Primary  \
# 0               346160                 2270664              1484300  16303716
# 1               224017                    8193                30842    716959
# 2               261987                  529539              1471149   5326697
# 3               550132                  653224                68107   8019997
# 5               597785                  385483              2451970   6400817
#
# ...

# %%
All_States['Total Contribution %'] = All_States['% Primary Contribution']+All_States['% Secondary Contribution']+All_States['% Tertiary Contribution']

# Sorting the dataframe to keep it in order.

All_States = All_States.sort_values(by='Total Contribution %',ascending=False)

# %%
All_States.head()
# Out:
#                States Agriculture, forestry and fishing   Crops Livestock  \
# 19           Nagaland                            607897  375825    123800
# 16            Manipur                            383140  226583     75483
# 27            Tripura                            799825  397591     88176
# 18            Mizoram                            217010  116609     45590
# 1   Arunachal_Pradesh                            686117  415520     38387
#
#    Forestry and logging Fishing and aquaculture Mining and quarrying Primary  \
# 19                99802                    8470                 8280  616178
# 16                45831                   35243                  NaN  383140
# 27               145096                  168961               142391  942216
# 18                47763                    7048                 8588  225598
# 1                224017                    8193                30842  716959
#
# ...

# %%
#Plot the percentage contribution of the primary, secondary and tertiary sectors 
#as a percentage of the total GDP for all the states.


Primary = All_States['% Primary Contribution']

Secondary = All_States['% Secondary Contribution']

Tertiary = All_States['% Tertiary Contribution']

States = All_States['States']   # the x locations for the groups

plt.figure(figsize=(14,6))

p1 = plt.bar(States, Primary)

p2 = plt.bar(States, Secondary, bottom=Primary)

p3 = plt.bar(States, Tertiary, bottom=np.array(Primary)+np.array(Secondary))

plt.ylabel('Total GSDP Percentage (%)')

plt.title('Percentage Contribution of Each sector to GSDP')

plt.xticks(States,rotation=90)

plt.yticks(np.arange(0, 110, 10)); plt.xlabel('All States Of India')

plt.legend((p1[0], p2[0], p3[0]), ('Primary', 'Secondary', 'Tertiary'))

plt.savefig(r'C:\Users\Admin\Downloads\GDP Assignment\Graph\% Contribution of eacg sectior to GSDP.png')

# %% [markdown]
# #### Plot the percentage contribution of the primary, secondary and tertiary sectors as a percentage of the total GDP for all the states.
#
# #### Which plot will you use here? Why?
# ##### Ans : Here I plotted the graph using Stacked Bar plot and required the total contribution of all the sector as total
#
# #### Why is (Primary + Secondary + Tertiary) not equal to total GDP?
# #### Ans : As per GDP can see that some states not contributing part of the total GDP.

# %%
#loading the data for this part

li_All_States = []
for file in all_files:
    df_All_states = pd.read_csv(file,encoding='latin1')
    df_All_states = df_All_states[['S.No.','Item','2014-15']]
    #df_All_states.columns = df_All_states.iloc[0]
    #df_All_states = df_All_states[1:]
    df_All_states['States'] = file.split('\\')[-1].split('-')[1]
    li_All_States.append(df_All_states)

# %%
GDP_All_States = pd.concat(li_All_States, axis = 0, ignore_index=True, sort= False)

# %%
GDP_All_States
# Out:
#      S.No.                                               Item      2014-15  \
# 0        1                  Agriculture, forestry and fishing   14819416.0
# 1      1.1                                              Crops    7893514.0
# 2      1.2                                          Livestock    4309078.0
# 3      1.3                               Forestry and logging     346160.0
# 4      1.4                            Fishing and aquaculture    2270664.0
# 5        2                               Mining and quarrying    1484300.0
# 6    Total                                            Primary   16303716.0
# 7        3                                      Manufacturing    4672266.0
# 8        4  Electricity, gas, water supply & other utility...    1151729.0
# 9        5                                       Construction    4664889.0
# 10   Total                                          Secondary   10488884.0
# ...

# %%
# set the index for this dataframe to states
GDP_All_States = GDP_All_States.set_index('States')

# %%
GDP_All_States
# Out:
#                 S.No.                                               Item  \
# States
# Andhra_Pradesh      1                  Agriculture, forestry and fishing
# Andhra_Pradesh    1.1                                              Crops
# Andhra_Pradesh    1.2                                          Livestock
# Andhra_Pradesh    1.3                               Forestry and logging
# Andhra_Pradesh    1.4                            Fishing and aquaculture
# Andhra_Pradesh      2                               Mining and quarrying
# Andhra_Pradesh  Total                                            Primary
# Andhra_Pradesh      3                                      Manufacturing
# Andhra_Pradesh      4  Electricity, gas, water supply & other utility...
# Andhra_Pradesh      5                                       Construction
# Andhra_Pradesh  Total                                          Secondary
# Andhra_Pradesh      6              Trade, repair, hotels and restaurants
# ...

# %%
# shape of this data
GDP_All_States.shape
# Out:
# (990, 3)

# %%
# droping the UN states for this dataset

GDP_All_States.drop(['Delhi'], inplace = True)

GDP_All_States.drop(['Chandigarh'], inplace = True)

GDP_All_States.drop(['Puducherry'], inplace = True)

# %%
# shape of this data
GDP_All_States.shape
# Out:
# (891, 3)

# %%
GDP_All_States
# Out:
#                 S.No.                                               Item  \
# States
# Andhra_Pradesh      1                  Agriculture, forestry and fishing
# Andhra_Pradesh    1.1                                              Crops
# Andhra_Pradesh    1.2                                          Livestock
# Andhra_Pradesh    1.3                               Forestry and logging
# Andhra_Pradesh    1.4                            Fishing and aquaculture
# Andhra_Pradesh      2                               Mining and quarrying
# Andhra_Pradesh  Total                                            Primary
# Andhra_Pradesh      3                                      Manufacturing
# Andhra_Pradesh      4  Electricity, gas, water supply & other utility...
# Andhra_Pradesh      5                                       Construction
# Andhra_Pradesh  Total                                          Secondary
# Andhra_Pradesh      6              Trade, repair, hotels and restaurants
# ...

# %%
#reset the data indext again as normal what we have earlier
GDP_All_States = GDP_All_States.reset_index()

# %%
# sorted the values per Capita GSDP (Rs.) and stored to new dataframe 
States_per_capita_value = GDP_All_States.loc[GDP_All_States.Item=='Per Capita GSDP (Rs.)'].sort_values(by='2014-15')

# %%
States_per_capita_value
# Out:
#                 States S.No.                   Item   2014-15
# 131              Bihar    17  Per Capita GSDP (Rs.)   33954.0
# 890      Uttar_Pradesh    17  Per Capita GSDP (Rs.)   49450.0
# 494            Manipur    17  Per Capita GSDP (Rs.)   58442.0
# 98               Assam    17  Per Capita GSDP (Rs.)   60621.0
# 329          Jharkhand    17  Per Capita GSDP (Rs.)   62091.0
# 428     Madhya_Pradesh    17  Per Capita GSDP (Rs.)   62989.0
# 626             Odisha    17  Per Capita GSDP (Rs.)   73979.0
# 527          Meghalaya    17  Per Capita GSDP (Rs.)   76228.0
# 824            Tripura    17  Per Capita GSDP (Rs.)   77358.0
# 692          Rajasthan    17  Per Capita GSDP (Rs.)   84837.0
# 164       Chhattisgarh    17  Per Capita GSDP (Rs.)   86860.0
# 593           Nagaland    17  Per Capita GSDP (Rs.)   89607.0
# 560            Mizoram    17  Per Capita GSDP (Rs.)   97687.0
# 32      Andhra_Pradesh    17  Per Capita GSDP (Rs.)  104977.0
# ...

# %%
# rename the coumns name

States_per_capita_value = GDP_All_States.loc[GDP_All_States.Item=='Per Capita GSDP (Rs.)'].sort_values(by='2014-15')[['2014-15','States']].rename(columns = {'2014-15':'States_per_capita_value'})

# %%
States_per_capita_value
# Out:
#      States_per_capita_value             States
# 131                  33954.0              Bihar
# 890                  49450.0      Uttar_Pradesh
# 494                  58442.0            Manipur
# 98                   60621.0              Assam
# 329                  62091.0          Jharkhand
# 428                  62989.0     Madhya_Pradesh
# 626                  73979.0             Odisha
# 527                  76228.0          Meghalaya
# 824                  77358.0            Tripura
# 692                  84837.0          Rajasthan
# 164                  86860.0       Chhattisgarh
# 593                  89607.0           Nagaland
# 560                  97687.0            Mizoram
# 32                  104977.0     Andhra_Pradesh
# 65                  112718.0  Arunachal_Pradesh
# 659                 126606.0             Punjab
# 791                 139035.0          Telangana
# 230                 141263.0            Gujarat
# 362                 145141.0          Karnataka
# ...

# %%
# Creating the categories C1, C2, C3, C4

Q1 = round(27*0.20) # total states count and then created the Quartile

Q2 = round(27*0.5)

Q3 = round(27*0.85)

Q4 = round(27*1)

C4 = States_per_capita_value.iloc[:Q1,:]

C3 = States_per_capita_value.iloc[Q1:Q2,:]

C2 = States_per_capita_value.iloc[Q2:Q3,:]

C1 = States_per_capita_value.iloc[Q3:Q4,:]

# %%
C1
# Out:
#      States_per_capita_value   States
# 395                 154778.0   Kerala
# 263                 164077.0  Haryana
# 725                 240274.0   Sikkim
# 197                 271793.0      Goa

# %%
#  C1 Category data

C1_GDP_All_States = GDP_All_States.loc[GDP_All_States.States.isin(C1.States)&(GDP_All_States['S.No.']!='Total')&
        (~GDP_All_States['Item'].isin(['TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products',"Population ('00)",'Per Capita GSDP (Rs.)']))]

# %%
# removing the unwanted data and sorting

C1_GDP_All_States = C1_GDP_All_States[['Item','2014-15']].groupby(by='Item').sum().sort_values(by='2014-15',ascending=False).reset_index()

# %%
# Creted the new columns %_of_GSDP_Contribution

C1_GDP_All_States['%_of_GSDP_Contribution'] = C1_GDP_All_States['2014-15']/(C1_GDP_All_States['2014-15'][0])*100 # here index index 0 has GSDP since we have sorted in descending order

# %%
# Finding which are the Sub-sectors that contribute approximately 80% to the GSDP 

start =1; End = 4

while C1_GDP_All_States.iloc[start:End ,-1].sum() <= 78: 
    End = End+1

# %%
# Contribution of subsectors approximately 80% For category C1 to the total GSDP are as follows

C1_GDP_States_Sub_Sectors_contributes_80_percent = C1_GDP_All_States[['Item','%_of_GSDP_Contribution']].iloc[start:End].append({'Item':'Total C1 Sub-Sectors','%_of_GSDP_Contribution':round(C1_GDP_All_States.iloc[start:End ,-1].sum(),2)},ignore_index=True).rename(columns={'Item':'C1 Sub Sectors contributes 80% to GSDP in total'})

# %%
C1_GDP_States_Sub_Sectors_contributes_80_percent
# Out:
#      C1 Sub Sectors contributes 80% to GSDP in total  %_of_GSDP_Contribution
# 0  Real estate, ownership of dwelling & professio...               14.461049
# 1                  Agriculture, forestry and fishing               14.119213
# 2              Trade, repair, hotels and restaurants               13.730076
# 3                                      Manufacturing               13.498187
# 4                                       Construction               11.051090
# 5                                     Other services                7.907258
# 6                                              Crops                7.811695
# 7                               Total C1 Sub-Sectors               82.580000

# %%
# Bar graph plot and which can show the top sub sectors which contributed 80 percent

plt.figure(figsize=(14,6))

C1_GDP_States_Sub_Sectors_contributes_80_percent.set_index("C1 Sub Sectors contributes 80% to GSDP in total").iloc[:-1,:]['%_of_GSDP_Contribution'].plot(kind='bar')

plt.ylabel('Sub Sectors GSDP Percentage (%)')
plt.xlabel('Sub-Sectors of C1')
plt.title('Top Sub Sectors That Contributed 80% (approx) of the C1 GSDP. Exact Contribution is: {0}%'.format(C1_GDP_States_Sub_Sectors_contributes_80_percent.iloc[-1:,-1:].values[0][0]))
plt.savefig(r'C:\Users\Admin\Downloads\GDP Assignment\Graph\C1 Sub Sectors That Contributed 80%.png')

# %%
#  C2 Category data

C2_GDP_All_States = GDP_All_States.loc[GDP_All_States.States.isin(C2.States)&(GDP_All_States['S.No.']!='Total')&
        (~GDP_All_States['Item'].isin(['TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products',"Population ('00)",'Per Capita GSDP (Rs.)']))]

# %%
C2
# Out:
#      States_per_capita_value             States
# 65                  112718.0  Arunachal_Pradesh
# 659                 126606.0             Punjab
# 791                 139035.0          Telangana
# 230                 141263.0            Gujarat
# 362                 145141.0          Karnataka
# 758                 146503.0         Tamil_Nadu
# 296                 147330.0   Himachal_Pradesh
# 461                 152853.0        Maharashtra
# 857                 153076.0        Uttarakhand

# %%
C2_GDP_All_States = C2_GDP_All_States[['Item','2014-15']].groupby(by='Item').sum().sort_values(by='2014-15',ascending=False).reset_index()

# %%
C2_GDP_All_States['%_of_GSDP_Contribution'] = C2_GDP_All_States['2014-15']/(C2_GDP_All_States['2014-15'][0])*100 # here index index 0 has GSDP since we have sorted in descending order

# %%
# Finding which are the Sub-sectors that contribute approximately 80% to the GSDP (It should be 3 or more)

start =1; End = 4 
while C2_GDP_All_States.iloc[start:End ,-1].sum() <= 78: 
    End = End+1

# %%
C2_GDP_States_Sub_Sectors_contributes_80_percent= C2_GDP_All_States[['Item','%_of_GSDP_Contribution']].iloc[start:End].append({'Item':'Total C2 Sub-Sectors','%_of_GSDP_Contribution':round(C2_GDP_All_States.iloc[start:End ,-1].sum(),2)},ignore_index=True).rename(columns={'Item':'C2 Sub Sectors contributes 80% to GSDP in total'})

# %%
C2_GDP_States_Sub_Sectors_contributes_80_percent
# Out:
#      C2 Sub Sectors contributes 80% to GSDP in total  %_of_GSDP_Contribution
# 0                                      Manufacturing               18.622130
# 1  Real estate, ownership of dwelling & professio...               15.710184
# 2                  Agriculture, forestry and fishing               12.825977
# 3              Trade, repair, hotels and restaurants               10.443537
# 4                            Trade & repair services                9.422608
# 5                                              Crops                8.109086
# 6                                       Construction                6.932967
# 7                               Total C2 Sub-Sectors               82.070000

# %%
# C3 Catgory data

C2_GDP_States_Sub_Sectors_contributes_80_percent.set_index("C2 Sub Sectors contributes 80% to GSDP in total").iloc[:-1,:]['%_of_GSDP_Contribution'].plot(kind='bar')

plt.ylabel('Sub Sectors GSDP Percentage (%)')
plt.xlabel('Sub-Sectors of C2')
plt.title('Top Sub Sectors That Contributed 80% (approx) of the C2 GSDP. Exact Contribution is: {0}%'.format(C2_GDP_States_Sub_Sectors_contributes_80_percent.iloc[-1:,-1:].values[0][0]))
plt.savefig(r'C:\Users\Admin\Downloads\GDP Assignment\Graph\C2 Sub Sectors That Contributed 80%.png')

# %%
C3_GDP_All_States= GDP_All_States.loc[GDP_All_States.States.isin(C3.States)&(GDP_All_States['S.No.']!='Total')&
        (~GDP_All_States['Item'].isin(['TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products',"Population ('00)",'Per Capita GSDP (Rs.)']))]

# %%
C3_GDP_All_States = C3_GDP_All_States[['Item','2014-15']].groupby(by='Item').sum().sort_values(by='2014-15',ascending=False).reset_index()



C3_GDP_All_States['%_of_GSDP_Contribution'] = C3_GDP_All_States['2014-15']/(C3_GDP_All_States['2014-15'][0])*100

# %%
start =1; End = 4 

while C3_GDP_All_States.iloc[start:End ,-1].sum() <= 78: 
    End = End+1
    

C3_GDP_States_Sub_Sectors_contributes_80_percent = C3_GDP_All_States[['Item','%_of_GSDP_Contribution']].iloc[start:End].append({'Item':'Total C3 Sub-Sectors ','%_of_GSDP_Contribution':round(C3_GDP_All_States.iloc[start:End ,-1].sum(),2)},ignore_index=True).rename(columns={'Item':'C3 Sub Sectors contributes 80% to GSDP in total'})

# %%
C3_GDP_States_Sub_Sectors_contributes_80_percent
# Out:
#   C3 Sub Sectors contributes 80% to GSDP in total  %_of_GSDP_Contribution
# 0               Agriculture, forestry and fishing               25.849557
# 1                                           Crops               16.312163
# 2                                   Manufacturing               11.676084
# 3           Trade, repair, hotels and restaurants                9.993973
# 4                         Trade & repair services                9.288358
# 5                                    Construction                8.892230
# 6                           Total C3 Sub-Sectors                82.010000

# %%
plt.figure(figsize=(14,6))


C3_GDP_States_Sub_Sectors_contributes_80_percent.set_index("C3 Sub Sectors contributes 80% to GSDP in total").iloc[:-1,:]['%_of_GSDP_Contribution'].plot(kind='bar')

plt.ylabel('Sub Sectors GSDP Percentage (%)')
plt.xlabel('Sub-Sectors of C3')

plt.title('Top Sub Sectors That Contributed 80% (approx) of the C3 GSDP. Exact Contribution is: {0}%'.format(C3_GDP_States_Sub_Sectors_contributes_80_percent.iloc[-1:,-1:].values[0][0]))

plt.savefig(r'C:\Users\Admin\Downloads\GDP Assignment\Graph\C3 Sub Sectors That Contributed 80%.png')

# %%
# C4 category

C4_GDP_All_States = GDP_All_States.loc[GDP_All_States.States.isin(C4.States)&(GDP_All_States['S.No.']!='Total')&
        (~GDP_All_States['Item'].isin(['TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products',"Population ('00)",'Per Capita GSDP (Rs.)']))]



C4_GDP_All_States = C4_GDP_All_States[['Item','2014-15']].groupby(by='Item').sum().sort_values(by='2014-15',ascending=False).reset_index()



C4_GDP_All_States['%_of_GSDP_Contribution'] = C4_GDP_All_States['2014-15']/(C4_GDP_All_States['2014-15'][0])*100 # here index index 0 has GSDP since we have sorted in descending order



start =1; End = 4 

while C4_GDP_All_States.iloc[start:End ,-1].sum() <= 78: #considering anything less than or equal to 78% does not contribute 80% approximately, only equal to greater than 79% does.
    End = End+1

# %%
C4_GDP_States_Sub_Sectors_contributes_80_percent = C4_GDP_All_States[['Item','%_of_GSDP_Contribution']].iloc[start:End].append({'Item':'Total C4 Sub-Sectors','%_of_GSDP_Contribution':round(C4_GDP_All_States.iloc[start:End ,-1].sum(),2)},ignore_index=True).rename(columns={'Item':'C4 Sub Sectors contributes 80% to GSDP in total'})

# %%
C4_GDP_States_Sub_Sectors_contributes_80_percent
# Out:
#      C4 Sub Sectors contributes 80% to GSDP in total  %_of_GSDP_Contribution
# 0                  Agriculture, forestry and fishing               21.885190
# 1                                              Crops               14.112128
# 2              Trade, repair, hotels and restaurants               11.957100
# 3  Real estate, ownership of dwelling & professio...               11.627645
# 4                                      Manufacturing               11.141726
# 5                            Trade & repair services               11.092776
# 6                               Total C4 Sub-Sectors               81.820000

# %%
plt.figure(figsize=(14,6))



C4_GDP_States_Sub_Sectors_contributes_80_percent.set_index("C4 Sub Sectors contributes 80% to GSDP in total").iloc[:-1,:]['%_of_GSDP_Contribution'].plot(kind='bar')

plt.ylabel('Sub Sectors GSDP Percentage (%)')
plt.xlabel('Sub-Sectors of C4')

plt.title('Top Sub Sectors That Contributed 80% (approx) of the C4 GSDP. Exact Contribution is: {0}%'.format(C4_GDP_States_Sub_Sectors_contributes_80_percent.iloc[-1:,-1:].values[0][0]))

plt.savefig(r'C:\Users\Admin\Downloads\GDP Assignment\Graph\C4 Sub Sectors That Contributed 80%.png')

# %%
# prited the average of C1 GSDP

print('Average of C1 GSDP: ',round(int(C1_GDP_All_States.iloc[0,1])/C1.shape[0]),', Per-capita AVG of C1 :', round(C1['States_per_capita_value'].mean()))

print('Average of C2 GSDP: ',round(int(C2_GDP_All_States.iloc[0,1])/C2.shape[0]),', Per-capita AVG of C2 :', round(C2['States_per_capita_value'].mean()))

print('Average of C3 GSDP: ',round(int(C3_GDP_All_States.iloc[0,1])/C3.shape[0]),', Per-capita AVG of C3 :', round(C3['States_per_capita_value'].mean()))

print('Average of C4 GSDP: ',round(int(C4_GDP_All_States.iloc[0,1])/C4.shape[0]),', Per-capita AVG of C4 :', round(C4['States_per_capita_value'].mean()))
# Out:
# Average of C1 GSDP:  25482669 , Per-capita AVG of C1 : 207730
# Average of C2 GSDP:  65153384 , Per-capita AVG of C2 : 140503
# Average of C3 GSDP:  25129395 , Per-capita AVG of C3 : 83836
# Average of C4 GSDP:  37010779 , Per-capita AVG of C4 : 52912

# %%
#sub-sectors seem to be correlated with high GDP

GDP_All_States[['Item','2014-15']].groupby('Item').sum().sort_values(by = '2014-15', ascending=False).head(11)
# Out:
#                                                          2014-15
# Item
# Gross State Domestic Product                        1.099530e+09
# TOTAL GSVA at basic prices                          1.008023e+09
# Tertiary                                            5.064437e+08
# Secondary                                           2.851220e+08
# Primary                                             2.164573e+08
# Agriculture, forestry and fishing                   1.885628e+08
# Manufacturing                                       1.699807e+08
# Real estate, ownership of dwelling & profession...  1.472633e+08
# Taxes on Products                                   1.217224e+08
# Trade, repair, hotels and restaurants               1.199639e+08
# Crops                                               1.185200e+08

# %%
# Sub-sectors which contributed lowest


print('Sub-sectors need to be focussed C1 Category: ',C1_GDP_All_States['Item'].tail().values,'\n')
# Out:
# Sub-sectors need to be focussed C1 Category:  ['Railways' 'Services incidental to transport' 'Air transport'
#  'Water transport' 'Storage']

# %%
# Sub-sectors which contributed lowest
print('Sub-sectors need to be focussed C2 Category:: ',C2_GDP_All_States['Item'].tail().values, '\n')
# Out:
# Sub-sectors need to be focussed C2 Category::  ['Services incidental to transport' 'Air transport' 'Storage'
#  'Water transport' 'Road transport*']

# %%
# Sub-sectors which contributed lowest
print('Sub-sectors need to be focussed C3 Category:: ',C3_GDP_All_States['Item'].tail().values, '\n')
# Out:
# Sub-sectors need to be focussed C3 Category::  ['Services incidental to transport' 'Water transport' 'Storage'
#  'Services incidental to transport*' 'Air transport']

# %%
# Sub-sectors which contributed lowest
print('Sub-sectors need to be focussed C4 Category:: ',C4_GDP_All_States['Item'].tail().values, '\n')
# Out:
# Sub-sectors need to be focussed C4 Category::  ['Hotels & restaurants' 'Services incidental to transport' 'Storage'
#  'Air transport' 'Water transport']

# %% [markdown]
# # Part-II: GDP and Education Dropout Rates

# %%
# loaded the data for Dropout

Dropout = pd.read_csv(r'C:\Users\Admin\Downloads\GDP Assignment\Data II download\State wise annual dropout rate.csv', encoding='latin1')
Dropout.head()
# Out:
#   Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0       1              A & N Islands                 0.68
# 1       2             Andhra Pradesh                 3.18
# 2       3          Arunachal Pradesh                15.16
# 3       4                      Assam                 6.24
# 4       5                      Bihar                  NaN
#
#    Primary - 2014-2015  Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# 0                 1.21                   0.51                       1.23
# 1                 4.35                   6.72                       3.36
# 2                10.89                  10.82                       7.47
# 3                 7.44                  15.36                       7.20
# 4                 2.09                    NaN                        NaN
#
#    Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# 0                       0.51                       1.69
# 1                       3.78                       5.20
# ...

# %%
# corrected the columns for this Dropout data

Dropout = Dropout.rename(columns = {'Primary - 2014-2015':'Primary - 2013-2014','Primary - 2014-2015.1':'Primary - 2014-2015','Level of Education - State':'States'})
Dropout
# Out:
#       Sl. No.                States  Primary - 2012-2013  Primary - 2013-2014  \
# 0           1         A & N Islands                 0.68                 1.21
# 1           2        Andhra Pradesh                 3.18                 4.35
# 2           3     Arunachal Pradesh                15.16                10.89
# 3           4                 Assam                 6.24                 7.44
# 4           5                 Bihar                  NaN                 2.09
# 5           6            Chandigarh                  NaN                  NaN
# 6           7           Chhatisgarh                 4.14                 1.42
# 7           8  Dadra & Nagar Haveli                  NaN                 1.57
# 8           9           Daman & Diu                  NaN                 0.85
# 9          10                 Delhi                  NaN                  NaN
# 10         11                   Goa                  NaN                 0.20
# ...

# %%
# 2014-2015 data need to visualize 

Dropout = Dropout[['States','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]

Dropout.head()
# Out:
#               States  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0      A & N Islands                 0.51                       1.69
# 1     Andhra Pradesh                 6.72                       5.20
# 2  Arunachal Pradesh                10.82                       6.71
# 3              Assam                15.36                      10.51
# 4              Bihar                  NaN                       4.08
#
#    Secondary - 2014-2015
# 0                   9.87
# 1                  15.71
# 2                  17.11
# 3                  27.06
# 4                  25.90

# %%
Dropout = Dropout.dropna(how='any')

Dropout
# Out:
#                   States  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0          A & N Islands                 0.51                       1.69
# 1         Andhra Pradesh                 6.72                       5.20
# 2      Arunachal Pradesh                10.82                       6.71
# 3                  Assam                15.36                      10.51
# 6            Chhatisgarh                 2.91                       5.85
# 7   Dadra & Nagar Haveli                 1.47                       4.02
# 8            Daman & Diu                 1.11                       3.11
# 10                   Goa                 0.73                       0.07
# 11               Gujarat                 0.89                       6.41
# 12               Haryana                 5.61                       5.81
# 13      Himachal Pradesh                 0.64                       0.87
# 14     Jammu and Kashmir                 6.79                       5.44
# ...

# %%
# Merge the data as per analysis

Dropout_per_capita_GSDP = pd.merge(GDP_All_States[GDP_All_States.Item == 'Per Capita GSDP (Rs.)'], Dropout, how = 'inner', on = 'States')

Dropout_per_capita_GSDP
# Out:
#          States S.No.                   Item   2014-15  Primary - 2014-2015  \
# 0         Assam    17  Per Capita GSDP (Rs.)   60621.0                15.36
# 1           Goa    17  Per Capita GSDP (Rs.)  271793.0                 0.73
# 2       Gujarat    17  Per Capita GSDP (Rs.)  141263.0                 0.89
# 3       Haryana    17  Per Capita GSDP (Rs.)  164077.0                 5.61
# 4     Jharkhand    17  Per Capita GSDP (Rs.)   62091.0                 5.48
# 5     Karnataka    17  Per Capita GSDP (Rs.)  145141.0                 2.02
# 6   Maharashtra    17  Per Capita GSDP (Rs.)  152853.0                 1.26
# 7       Manipur    17  Per Capita GSDP (Rs.)   58442.0                 9.66
# 8     Meghalaya    17  Per Capita GSDP (Rs.)   76228.0                 9.46
# 9       Mizoram    17  Per Capita GSDP (Rs.)   97687.0                10.10
# 10     Nagaland    17  Per Capita GSDP (Rs.)   89607.0                 5.61
# ...

# %%
# Created new coulmns and added the data

Dropout_per_capita_GSDP['Total_dropout_in_2014-15'] = Dropout_per_capita_GSDP.iloc[:,-3:].sum(axis = 1)

Dropout_per_capita_GSDP
# Out:
#          States S.No.                   Item   2014-15  Primary - 2014-2015  \
# 0         Assam    17  Per Capita GSDP (Rs.)   60621.0                15.36
# 1           Goa    17  Per Capita GSDP (Rs.)  271793.0                 0.73
# 2       Gujarat    17  Per Capita GSDP (Rs.)  141263.0                 0.89
# 3       Haryana    17  Per Capita GSDP (Rs.)  164077.0                 5.61
# 4     Jharkhand    17  Per Capita GSDP (Rs.)   62091.0                 5.48
# 5     Karnataka    17  Per Capita GSDP (Rs.)  145141.0                 2.02
# 6   Maharashtra    17  Per Capita GSDP (Rs.)  152853.0                 1.26
# 7       Manipur    17  Per Capita GSDP (Rs.)   58442.0                 9.66
# 8     Meghalaya    17  Per Capita GSDP (Rs.)   76228.0                 9.46
# 9       Mizoram    17  Per Capita GSDP (Rs.)   97687.0                10.10
# 10     Nagaland    17  Per Capita GSDP (Rs.)   89607.0                 5.61
# ...

# %%
# Graph for  Dropout rates and GSDP and created the sub plot for each all the required columns

X = Dropout_per_capita_GSDP['2014-15'].values 

Y1 = Dropout_per_capita_GSDP['Primary - 2014-2015'].values 

Y2 = Dropout_per_capita_GSDP['Upper Primary - 2014-2015'].values 

Y3 = Dropout_per_capita_GSDP['Secondary - 2014-2015'].values

Y4 = Dropout_per_capita_GSDP['Total_dropout_in_2014-15'].values

plt.figure(figsize=(12,10))

plt.subplot(2,2,1)

plt.title('GSDP vs Dropout Rate in Primary During 2014-2015')

plt.xlabel('GSDP in Crores (Rs.)')

plt.ylabel('Dropout rate in Percentage')

plt.scatter(X,Y1)

plt.subplot(2,2,2)

plt.title('GSDP vs Dropout Rate in Upper-Primary During 2014-2015')

plt.xlabel('GSDP in Crores (Rs.)')

plt.ylabel('Dropout rate in Percentage')

plt.scatter(X,Y2)

plt.subplot(2,2,3)

plt.title('GSDP vs Dropout Rate in Secondary During 2014-2015')

plt.xlabel('GSDP in Crores (Rs.)')

plt.ylabel('Dropout rate in Percentage')

plt.scatter(X,Y3)

plt.subplot(2,2,4)

plt.title('GSDP vs Total Dropout Rate During 2014-2015')

plt.xlabel('GSDP in Crores (Rs.)')

plt.ylabel('Dropout rate in Percentage')

plt.scatter(X,Y4)

plt.savefig(r'C:\Users\Admin\Downloads\GDP Assignment\Graph\GSDP vs Total Dropout Rate During 2014-2015.png')

# %%
#I can observer that all states Per capita less than 150000 are majorly those having drop out more than 15.
#I can say that - increase the per capita if decrease the dropout rate below 15
